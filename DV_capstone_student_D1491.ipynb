# %% [markdown]
# <a href="https://colab.research.google.com/github/bpunar/DATA-SCIENCE-CLARUSWAY-/blob/main/DV_capstone_student_D1491.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df = pd.read_csv("store_sharing.csv")
df.head()
# Out:
#              timestamp  cnt   t1  ...  is_holiday  is_weekend  season
# 0  2015-01-04 00:00:00  182  3.0  ...         0.0         1.0     3.0
# 1  2015-01-04 01:00:00  138  3.0  ...         0.0         1.0     3.0
# 2  2015-01-04 02:00:00  134  2.5  ...         0.0         1.0     3.0
# 3  2015-01-04 03:00:00   72  2.0  ...         0.0         1.0     3.0
# 4  2015-01-04 04:00:00   47  2.0  ...         0.0         1.0     3.0
#
# [5 rows x 10 columns]

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
# season

sns.countplot(x="season", data= df);

# %%
# is_holiday
sns.countplot(x="is_holiday", data= df);

# %%
# is_weekend
sns.countplot(x="is_weekend", data= df);

# %%
# weather_code
sns.countplot(x="weather_code", data= df);

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.timestamp = pd.to_datetime(df.timestamp, format='%Y/%m/%d %H:%M:%S')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
df.head(1)
# Out:
#    timestamp  cnt   t1   t2  ...  weather_code  is_holiday  is_weekend  season
# 0 2015-01-04  182  3.0  2.0  ...           3.0         0.0         1.0     3.0
#
# [1 rows x 10 columns]

# %%
#df.set_index(df.timestamp)
#df.head()
#ben bunu daha sonra yaptım.Önce aşağıdaki ilmeleri yaptım. çünkü sütın oluşturma işlemlerini aksi halde yapamazdım ?????????????????

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df['year_month'] = df['timestamp'].dt.to_period('M')
df['year'] = df['timestamp'].dt.year
df['month'] = df['timestamp'].dt.month
df['day_of_month'] = df['timestamp'].dt.day
df['day_of_week'] = df['timestamp'].dt.dayofweek
df['hour'] = df['timestamp'].dt.hour

# %%
df.head()
# Out:
#             timestamp  cnt   t1   t2  ...  month  day_of_month  day_of_week  hour
# 0 2015-01-04 00:00:00  182  3.0  2.0  ...      1             4            6     0
# 1 2015-01-04 01:00:00  138  3.0  2.5  ...      1             4            6     1
# 2 2015-01-04 02:00:00  134  2.5  2.5  ...      1             4            6     2
# 3 2015-01-04 03:00:00   72  2.0  2.0  ...      1             4            6     3
# 4 2015-01-04 04:00:00   47  2.0  0.0  ...      1             4            6     4
#
# [5 rows x 16 columns]

# %%
df = df.set_index(df.timestamp)
df = df.drop("timestamp", axis=1)
df.head()
# Out:
#                      cnt   t1   t2  ...  day_of_month  day_of_week  hour
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...             4            6     0
# 2015-01-04 01:00:00  138  3.0  2.5  ...             4            6     1
# 2015-01-04 02:00:00  134  2.5  2.5  ...             4            6     2
# 2015-01-04 03:00:00   72  2.0  2.0  ...             4            6     3
# 2015-01-04 04:00:00   47  2.0  0.0  ...             4            6     4
#
# [5 rows x 15 columns]

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
plt.figure(figsize = (15,8))
sns.heatmap(data=df.corr(), annot=True, cmap="Blues");
#rengi ayarlayamadım ???????????????????????

# %%
# for all variables

# %%
plt.figure(figsize = (2, 6))
ax=sns.heatmap(df.corr()[['cnt']].sort_values(by="cnt", ascending=False), annot=True, cmap="BrBG");
#rengi ayarlayamadım ????????????????????**

# %%
# for the target variable

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
#with pandas
#############yapamadım ??????????????????***

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize = (15,6))
sns.lineplot(data = df['cnt']);

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
plt.figure(figsize = (10,5))
sns.lineplot(x ="year_month",
              y = "cnt",
              data = df);

# %%
###bunu yapamadım. gercekten çok merak ediyorum bu kadar basit bir grafiği nasıl yapamadığımı ??????????????

# %%
# with lineplot

# %%
# with lineplot
plt.figure(figsize = (10,5))
sns.lineplot(x = "month",
              y = "cnt",
              data = df);

# %%
# with pointplot
plt.figure(figsize = (15,5))
sns.pointplot(x = "month",
              y = "cnt",
              data = df);

# %%
# with barplot
plt.figure(figsize = (10,5))
sns.barplot(x="month", y="cnt", data=df);

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize = (20,5))
sns.lineplot(x = "hour",
              y = "cnt",
             hue="is_holiday",
              data = df);

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize = (15,5))
sns.lineplot(x = "hour",
              y = "cnt",
             hue="season",
              data = df);

# %%
# with pointplot
plt.figure(figsize = (18,3))
sns.pointplot(x = "hour",
              y = "cnt",
              data = df);

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
# with barplot
sns.barplot(x="day_of_week", y="cnt", data=df, hue="is_weekend");

# %%
plt.figure(figsize = (15,3))
sns.pointplot(x = "day_of_week",
              y = "cnt",
              data = df);
#bunu yapamadım ?????????????????????????????***

# %%
# with pointplot

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
#with lineplot
df_1 = pd.DataFrame(df.groupby("day_of_month")["cnt"].mean().round())
df_1 = df_1.reset_index()
df_1 = df_1.set_index("day_of_month")
df_1.T
# Out:
# day_of_month      1       2       3       4   ...      28      29      30     31
# cnt           1077.0  1088.0  1128.0  1144.0  ...  1063.0  1080.0  1156.0  968.0
#
# [1 rows x 31 columns]

# %%
plt.figure(figsize = (15,5))
sns.lineplot(x = "day_of_month",
              y = "cnt",
             data = df);

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
# with barplot
plt.figure(figsize = (10,6))
sns.barplot(x="year", y="cnt", data=df);

# %%
#plt.figure(figsize = (10,6))
sns.barplot(x="season", y="cnt", data=df);
#anlamadım niye 2. yok ki?

# %%
# with barplot

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df.is_weekend.value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
# pie chart
labels = 'weekday', 'weekend'
df.is_weekend.value_counts().plot.pie(figsize=(5,5),labeldistance=1.1, labels=labels, autopct="%.1f%%", startangle=0)
plt.show()

# %%
weekday = df.is_weekend.value_counts()[0]
weekend = df.is_weekend.value_counts()[1]
weekday_ratio = round((weekday/ (weekday+weekend)*100),1)
weekend_ratio = round((weekend/ (weekday+weekend)*100),1)

# %%
sns.countplot(x="is_weekend", data= df);

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.2, p.get_height()+20));
    #burada sütun üstlerine label ekleyemedim.

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
# with countplot
sns.countplot(x="weather_code", data= df);

# %%
# with catplot
sns.catplot(x="weather_code", kind="count", data=df, col="season");

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# belki biazr daha zama olsa idi yapabilirdim. deadline pzartesi olsa daha iyi olurdu.
